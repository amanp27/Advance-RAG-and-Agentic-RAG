# %%
import os
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create a list of documents with metadata
docs = [
    Document(page_content="Rockets work by expelling gas at high speed, generating thrust through Newton's third law of motion.",
             metadata={"topic": "space"}),
    Document(page_content="The International Space Station orbits Earth at about 400 km altitude and travels at 28,000 km/h.",
             metadata={"topic": "space"}),
    Document(page_content="Spacecraft use gravitational slingshots around planets to gain speed without burning extra fuel.",
             metadata={"topic": "space"}),
    Document(page_content="NASA's Voyager 1 is the farthest human-made object, now over 23 billion km from the Sun.",
             metadata={"topic": "space"}),
    Document(page_content="Solar sails use radiation pressure from sunlight to slowly propel spacecraft without fuel.",
             metadata={"topic": "space"}),
    Document(page_content="DNA is a double-helix molecule that carries the genetic instructions for all living organisms.",
             metadata={"topic": "biology"}),
    Document(page_content="Photosynthesis allows plants to convert sunlight, water, and CO2 into glucose and oxygen.",
             metadata={"topic": "biology"}),
    Document(page_content="The Roman Empire at its peak covered over 5 million square kilometers across three continents.",
             metadata={"topic": "history"}),
    Document(page_content="The printing press, invented by Gutenberg around 1440, revolutionised the spread of knowledge.",
             metadata={"topic": "history"}),
    Document(page_content="The Amazon River discharges more freshwater into the ocean than any other river on Earth.",
             metadata={"topic": "geography"}),
    Document(page_content="The Sahara Desert spans about 9.2 million square kilometers across northern Africa.",
             metadata={"topic": "geography"}),
    Document(page_content="Mitochondria generate ATP through cellular respiration, powering nearly all cellular processes.",
             metadata={"topic": "biology"}),
]

# %%
for ind, doc in enumerate(docs, 1):
    print(f"Doc No.- {ind} | MetaData- {doc.metadata}")
    print(f"Page Content: {doc.page_content}")
    print("-"*60)
# Out:
# Doc No.- 1 | MetaData- {'topic': 'space'}
# Page Content: Rockets work by expelling gas at high speed, generating thrust through Newton's third law of motion.
# ------------------------------------------------------------
# Doc No.- 2 | MetaData- {'topic': 'space'}
# Page Content: The International Space Station orbits Earth at about 400 km altitude and travels at 28,000 km/h.
# ------------------------------------------------------------
# Doc No.- 3 | MetaData- {'topic': 'space'}
# Page Content: Spacecraft use gravitational slingshots around planets to gain speed without burning extra fuel.
# ------------------------------------------------------------
# Doc No.- 4 | MetaData- {'topic': 'space'}
# Page Content: NASA's Voyager 1 is the farthest human-made object, now over 23 billion km from the Sun.
# ------------------------------------------------------------
# Doc No.- 5 | MetaData- {'topic': 'space'}
# Page Content: Solar sails use radiation pressure from sunlight to slowly propel spacecraft without fuel.
# ------------------------------------------------------------
# Doc No.- 6 | MetaData- {'topic': 'biology'}
# Page Content: DNA is a double-helix molecule that carries the genetic instructions for all living organisms.
# ------------------------------------------------------------
# Doc No.- 7 | MetaData- {'topic': 'biology'}
# Page Content: Photosynthesis allows plants to convert sunlight, water, and CO2 into glucose and oxygen.
# ------------------------------------------------------------
# Doc No.- 8 | MetaData- {'topic': 'history'}
# Page Content: The Roman Empire at its peak covered over 5 million square kilometers across three continents.
# ------------------------------------------------------------
# Doc No.- 9 | MetaData- {'topic': 'history'}
# Page Content: The printing press, invented by Gutenberg around 1440, revolutionised the spread of knowledge.
# ------------------------------------------------------------
# Doc No.- 10 | MetaData- {'topic': 'geography'}
# Page Content: The Amazon River discharges more freshwater into the ocean than any other river on Earth.
# ------------------------------------------------------------
# Doc No.- 11 | MetaData- {'topic': 'geography'}
# Page Content: The Sahara Desert spans about 9.2 million square kilometers across northern Africa.
# ------------------------------------------------------------
# Doc No.- 12 | MetaData- {'topic': 'biology'}
# Page Content: Mitochondria generate ATP through cellular respiration, powering nearly all cellular processes.
# ------------------------------------------------------------

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

vectorstore = Chroma.from_documents(
    documents=docs,
    embedding=embeddings,
    collection_name="similarity_search_demo"
)

# %%
vectorstore.get()
# Out:
# {'ids': ['08d24708-8b0a-4ef5-9a03-d184127b3121',
#   'ba1c3a8e-efb0-4af6-b0eb-33d8910ad142',
#   '256eae83-bdc3-410b-83a0-b0e194ecdc04',
#   '51985fce-40c7-4656-8949-ffb43632dc58',
#   '28e6a406-106d-47b1-bd63-8f29916b5442',
#   '8b79020f-7b97-4bd5-9248-38c1f1e5cc80',
#   '0acb6ccd-5323-4224-9257-dad77d9dc094',
#   'f76dbe3d-3b8d-440d-933b-ef883e2b0a71',
#   '73e20a96-9422-413c-8ba1-7eff5ef8ed3e',
#   '63fcbfdf-abf4-41a3-a09a-b192d5ce5a67',
#   '000bef51-5467-4a10-b1c2-5453b35a802d',
#   '07f30567-0907-4791-851b-211cf5b24248'],
#  'embeddings': None,
#  'documents': ["Rockets work by expelling gas at high speed, generating thrust through Newton's third law of motion.",
#   'The International Space Station orbits Earth at about 400 km altitude and travels at 28,000 km/h.',
#   'Spacecraft use gravitational slingshots around planets to gain speed without burning extra fuel.',
#   "NASA's Voyager 1 is the farthest human-made object, now over 23 billion km from the Sun.",
#   'Solar sails use radiation pressure from sunlight to slowly propel spacecraft without fuel.',
#   'DNA is a double-helix molecule that carries the genetic instructions for all living organisms.',
#   'Photosynthesis allows plants to convert sunlight, water, and CO2 into glucose and oxygen.',
#   'The Roman Empire at its peak covered over 5 million square kilometers across three continents.',
#   'The printing press, invented by Gutenberg around 1440, revolutionised the spread of knowledge.',
#   'The Amazon River discharges more freshwater into the ocean than any other river on Earth.',
#   'The Sahara Desert spans about 9.2 million square kilometers across northern Africa.',
#   'Mitochondria generate ATP through cellular respiration, powering nearly all cellular processes.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'topic': 'space'},
#   {'topic': 'space'},
#   {'topic': 'space'},
#   {'topic': 'space'},
#   {'topic': 'space'},
#   {'topic': 'biology'},
#   {'topic': 'biology'},
#   {'topic': 'history'},
#   {'topic': 'history'},
#   {'topic': 'geography'},
#   {'topic': 'geography'},
#   {'topic': 'biology'}]}

# %%
retriever = vectorstore.as_retriever(
    search_type = "similarity",
    search_kwargs = {'k': 3}
)

# %%
query = "How do cells generate energy?"

results = retriever.invoke(query)
results
# Out:
# [Document(id='07f30567-0907-4791-851b-211cf5b24248', metadata={'topic': 'biology'}, page_content='Mitochondria generate ATP through cellular respiration, powering nearly all cellular processes.'),
#  Document(id='0acb6ccd-5323-4224-9257-dad77d9dc094', metadata={'topic': 'biology'}, page_content='Photosynthesis allows plants to convert sunlight, water, and CO2 into glucose and oxygen.'),
#  Document(id='28e6a406-106d-47b1-bd63-8f29916b5442', metadata={'topic': 'space'}, page_content='Solar sails use radiation pressure from sunlight to slowly propel spacecraft without fuel.')]

# %%
print(f"Query- {query}")
for i, doc in enumerate(results, 1):
    print(f"Doc No.- {i} | Metadata: {doc.metadata}")
    print(f"Page Content- {doc.page_content}")
    print("\n--\n")
# Out:
# Query- How do cells generate energy?
# Doc No.- 1 | Metadata: {'topic': 'biology'}
# Page Content- Mitochondria generate ATP through cellular respiration, powering nearly all cellular processes.
#
# --
#
# Doc No.- 2 | Metadata: {'topic': 'biology'}
# Page Content- Photosynthesis allows plants to convert sunlight, water, and CO2 into glucose and oxygen.
#
# --
#
# Doc No.- 3 | Metadata: {'topic': 'space'}
# Page Content- Solar sails use radiation pressure from sunlight to slowly propel spacecraft without fuel.
#
# --
